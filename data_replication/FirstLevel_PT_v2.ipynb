# %%
from nilearn import plotting
# %matplotlib inline
from os.path import join as opj
import json
from nipype.interfaces.spm import Level1Design, EstimateModel, EstimateContrast
from nipype.algorithms.modelgen import SpecifySPMModel
from nipype.interfaces.utility import Function, IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype import Workflow, Node
# Out:
# /home/soyeon/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('/opt/spm12')

# %%
experiment_dir = '/data/EFAT/EFAT_output/PT'
output_dir = 'datasink'
working_dir = 'workingdir'

# list of subject identifiers
subject_list = [
                  
                 
               
                
                '058', '060', '066',  
                '074', '075', '080', 
                '082', '083', '084', '086', '087', '089', 
                '095', '096', '101', '103', 
                '104', '105', '106', '108', 
                '113', '114', '117', '118', '120', '121', 
                '124', '125', '128', '131', 
                '134', '136', '138', '140', '141', 
                '142', '143', '146', '150', 
                '153', '156', '159', '160', '162', '165', 
                '168', '169', '171', '181', '182', 
                '183', '190', '193', '199', 
                '201', '205', '206', '209', '212']

# 031, 027, 028, 034, 047, 049,
# 010, 014, 006, 017, 016, 021,
# 024, 042, 013, 004, 003, 045,
# 005, 043, 011, 038, 037, 009,
# 018, 044, 007, 033
fwhm = [8]

TR = 2.0

# %%
def make_input_list(func1, func2):
    input_list = [func1, func2]
    return input_list

make_input1 = Node(Function(input_names = ['func1', 'func2'],
                 output_names = ['input_list_func'],
                 function = make_input_list),
                 name = 'make_input1')

def make_param_list(mc_param1, mc_param2):
    input_list = [mc_param1, mc_param2]
    return input_list

make_input2 = Node(Function(input_names = ['mc_param1', 'mc_param2'],
                 output_names = ['input_list_param'],
                 function = make_param_list),
                 name = 'make_input2')

def make_out_list(outliers1, outliers2):
    input_list = [outliers1, outliers2]
    return input_list

make_input3 = Node(Function(input_names = ['outliers1', 'outliers2'],
                 output_names = ['input_list_out'],
                 function = make_out_list),
                 name = 'make_input3')

# %%
# SpecifyModel - Generates SPM-specific Model
modelspec = Node(SpecifySPMModel(concatenate_runs=False,
                                 input_units='secs',
                                 output_units='secs',
                                 time_repetition=TR,
                                 high_pass_filter_cutoff=128),
                 name="modelspec")

# Level1Design - Generates an SPM design matrix
level1design = Node(Level1Design(bases={'hrf': {'derivs': [1, 0]}},
                                 timing_units='secs',
                                 interscan_interval=TR,
                                 model_serial_correlations='FAST'),
                    name="level1design")

# EstimateModel - estimate the parameters of the model
level1estimate = Node(EstimateModel(estimation_method={'Classical': 1}),
                      name="level1estimate")

# EstimateContrast - estimates contrasts
level1conest = Node(EstimateContrast(), name="level1conest")

# %%
condition_names = ['angry', 'fear', 'happy', 'sad', 'shapes']

cont01 = ['average',        'T', condition_names, [1/5., 1/5., 1/5., 1/5., 1/5]]
cont02 = ['angry',          'T', condition_names, [1, 0, 0, 0, 0]]
cont03 = ['fear',           'T', condition_names, [0, 1, 0, 0, 0]]
cont04 = ['happy',          'T', condition_names, [0, 0, 1, 0, 0]]
cont05 = ['sad',            'T', condition_names, [0, 0, 0, 1, 0]]
cont06 = ['shapes',         'T', condition_names, [0, 0, 0, 0, 1]]
cont07 = ['angry > shapes', 'T', condition_names, [1, 0, 0, 0, -1]]
cont08 = ['fear > shapes',  'T', condition_names, [0, 1, 0, 0, -1]]
cont09 = ['happy > shapes', 'T', condition_names, [0, 0, 1, 0, -1]]
cont10 = ['sad > shapes',   'T', condition_names, [0, 0, 0, 1, -1]]

cont11 = ['activation',     'F', [cont02, cont03, cont04, cont05, cont06]]
cont12 = ['difference',     'F', [cont07, cont08, cont09, cont10]]

contrast_list = [cont01, cont02, cont03, cont04, cont05, cont06, 
                 cont07, cont08, cont09, cont10, cont11, cont12]

# %%
def subjectinfo(subject_id):

    import pandas as pd
    from nipype.interfaces.base import Bunch
    
    trialinfo1 = pd.read_table('/data/EFAT/EFAT_RawData/PT/sub-%s/func/sub-%s_task-EFAT_run-01_events.tsv' % (subject_id,subject_id))
   
    trialinfo1.head()
    
    
    conditions1 = []
    onsets1 = []
    durations1 = []
        
    for group in trialinfo1.groupby('trial_type'):
        conditions1.append(group[0])
        onsets1.append(list(group[1].onset - 8)) # subtracting 8s due to removing of 4 dummy scans
        durations1.append(group[1].duration.tolist())
            
    subject_info1 = Bunch(conditions=conditions1,
                            onsets=onsets1,
                            durations=durations1)
                            #amplitudes=None,
                            #tmod=None,
                            #pmod=None,
                            #regressor_names=None,
                            #regressors=None
    
    trialinfo2 = pd.read_table('/data/EFAT/EFAT_RawData/PT/sub-%s/func/sub-%s_task-EFAT_run-02_events.tsv' % (subject_id,subject_id))
    trialinfo2.head()
    conditions2 = []
    onsets2 = []
    durations2 = []
            
    for group in trialinfo2.groupby('trial_type'):
        conditions2.append(group[0])
        onsets2.append(list(group[1].onset - 8))
        durations2.append(group[1].duration.tolist())
                
    subject_info2 = Bunch(conditions=conditions2,
                            onsets=onsets2,
                            durations=durations2)
        
    subject_info = [subject_info1, subject_info2]

    return subject_info # this output will later be returned to infosource

# Get Subject Info - get subject specific condition information
getsubjectinfo = Node(Function(input_names=['subject_id'],
                               output_names=['subject_info'],
                               function=subjectinfo),
                      name='getsubjectinfo')

# %%
import pandas as pd
from nipype.interfaces.base import Bunch

# %%
def subjectinfo(subject_id):

    import pandas as pd
    from nipype.interfaces.base import Bunch
    
    trialinfo1 = pd.read_table('/data/EFAT/EFAT_RawData/PT/sub-%s/func/sub-%s_task-EFAT_run-01_events.tsv' % (subject_id,subject_id))
   
    trialinfo1.head()
    conditions1 = []
    onsets1 = []
    durations1 = []
        
    for group in trialinfo1.groupby('trial_type'):
        conditions1.append(group[0])
        onsets1.append(list(group[1].onset - 8)) # subtracting 8s due to removing of 4 dummy scans
        durations1.append(group[1].duration.tolist())
            
    subject_info1 = Bunch(conditions=conditions1,
                            onsets=onsets1,
                            durations=durations1)
                            #amplitudes=None,
                            #tmod=None,
                            #pmod=None,
                            #regressor_names=None,
                            #regressors=None
    
    trialinfo2 = pd.read_table('/data/EFAT/EFAT_RawData/PT/sub-%s/func/sub-%s_task-EFAT_run-02_events.tsv' % (subject_id,subject_id))
    trialinfo2.head()
    conditions2 = []
    onsets2 = []
    durations2 = []
            
    for group in trialinfo2.groupby('trial_type'):
        conditions2.append(group[0])
        onsets2.append(list(group[1].onset - 8))
        durations2.append(group[1].duration.tolist())
                
    subject_info2 = Bunch(conditions=conditions2,
                            onsets=onsets2,
                            durations=durations2)
        
    subject_info = [subject_info1, subject_info2]

    return subject_info # this output will later be returned to infosource

# Get Subject Info - get subject specific condition information
getsubjectinfo = Node(Function(input_names=['subject_id'],
                               output_names=['subject_info'],
                               function=subjectinfo),
                      name='getsubjectinfo')

# %%
# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id',
                                            'fwhm_id',
                                            'contrasts'],
                                    contrasts=contrast_list),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list),
                        ('fwhm_id', fwhm)]

# SelectFiles - to grab the data (alternativ to DataGrabber)
templates = {'func1': opj(output_dir, 'norm_spm', 'sub-{subject_id}_fwhm8',
                         'run-01', 'wfwhm-8_ssub-{subject_id}_task-EFAT_run-01_bold.nii'),
             'func2': opj(output_dir, 'norm_spm', 'sub-{subject_id}_fwhm8',
                         'run-02', 'wfwhm-8_ssub-{subject_id}_task-EFAT_run-02_bold.nii'),
             'mc_param1': opj(output_dir, 'preproc', 'sub-{subject_id}', 'task-EFAT',
                             'run-01', 'sub-{subject_id}_task-EFAT_run-01_bold.par'),
             'mc_param2': opj(output_dir, 'preproc', 'sub-{subject_id}', 'task-EFAT',
                             'run-02', 'sub-{subject_id}_task-EFAT_run-02_bold.par'),
             'outliers1': opj(output_dir, 'preproc', 'sub-{subject_id}', 'task-EFAT', 
                             'run-01', 'art.sub-{subject_id}_task-EFAT_run-01_bold_outliers.txt'),
             'outliers2': opj(output_dir, 'preproc', 'sub-{subject_id}', 'task-EFAT', 
                             'run-02', 'art.sub-{subject_id}_task-EFAT_run-02_bold_outliers.txt')}
selectfiles = Node(SelectFiles(templates,
                               base_directory=experiment_dir,
                               sort_filelist=True),
                   name="selectfiles")
selectfiles.inputs.task_id = 'EFAT'

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

# Use the following DataSink output substitutions
substitutions = [('_subject_id_', 'sub-')]
subjFolders = [('_fwhm_id_%ssub-%s' % (f, sub), 'sub-%s/fwhm-%s' % (sub, f))
               for f in fwhm
               for sub in subject_list]
substitutions.extend(subjFolders)
datasink.inputs.substitutions = substitutions

# %%
# Initiation of the 1st-level analysis workflow
l1analysis = Workflow(name='l1analysis')
l1analysis.base_dir = opj(experiment_dir, working_dir)

# Connect up the 1st-level analysis components
l1analysis.connect([(infosource, selectfiles, [('subject_id', 'subject_id'),
                                               ('fwhm_id', 'fwhm_id'),]),
                    (infosource, getsubjectinfo, [('subject_id',
                                                   'subject_id')]),
                    (getsubjectinfo, modelspec, [('subject_info',
                                                  'subject_info')]),
                    (infosource, level1conest, [('contrasts', 'contrasts')]),
                    
                    (selectfiles, make_input1, [('func1', 'func1')]),
                    (selectfiles, make_input1, [('func2', 'func2')]),
                    (make_input1, modelspec, [('input_list_func', 'functional_runs')]),
                    
                    (selectfiles, make_input2, [('mc_param1', 'mc_param1')]),
                    (selectfiles, make_input2, [('mc_param2', 'mc_param2')]),
                    (make_input2, modelspec, [('input_list_param', 'realignment_parameters')]),
                    
                    (selectfiles, make_input3, [('outliers1', 'outliers1')]),
                    (selectfiles, make_input3, [('outliers2', 'outliers2')]),
                    (make_input3, modelspec, [('input_list_out', 'outlier_files')]),
                                   
                    (modelspec, level1design, [('session_info',
                                                'session_info')]),
                    (level1design, level1estimate, [('spm_mat_file',
                                                     'spm_mat_file')]),
                    (level1estimate, level1conest, [('spm_mat_file',
                                                     'spm_mat_file'),
                                                    ('beta_images',
                                                     'beta_images'),
                                                    ('residual_image',
                                                     'residual_image'),
                                                   ]),
                    (level1estimate, datasink, [('mask_image', '1stLevel.@mask')]),
                    (level1conest, datasink, [('spm_mat_file', '1stLevel.@spm_mat'),
                                              ('spmT_images', '1stLevel.@T'),
                                              ('con_images', '1stLevel.@con'),
                                              ('spmF_images', '1stLevel.@F'),
                                              ('ess_images', '1stLevel.@ess'),
                                              ]),
                    ])

# %%
# Create 1st-level analysis output graph
l1analysis.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=opj(l1analysis.base_dir, 'l1analysis', 'graph.png'))
# Out:
# 190124-14:35:30,792 nipype.workflow INFO:
# 	 Generated workflow graph: /data/EFAT/EFAT_output/PT/workingdir/l1analysis/graph.png (graph2use=colored, simple_form=True).

# %%
l1analysis.run('MultiProc', plugin_args={'n_procs': 7})
# Out:
# 190124-14:35:35,235 nipype.workflow INFO:
# 	 Workflow l1analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 190124-14:35:36,620 nipype.workflow INFO:
# 	 Running in parallel.
# 190124-14:35:36,641 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 118 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:35:36,811 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_212/selectfiles".
# 190124-14:35:36,833 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190124-14:35:36,838 nipype.workflow INFO:
# 	 [Job 4] Cached (l1analysis.getsubjectinfo).
# 190124-14:35:36,849 nipype.workflow INFO:
# 	 [Job 14] Cached (l1analysis.getsubjectinfo).
# 190124-14:35:36,856 nipype.workflow INFO:
# 	 [Job 24] Cached (l1analysis.getsubjectinfo).
# 190124-14:35:36,858 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_206/selectfiles".
# 190124-14:35:36,909 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190124-14:35:36,851 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_209/selectfiles".
# 190124-14:35:36,922 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 190124-14:35:36,929 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")190124-14:35:36,869 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_205/selectfiles".
#
# 190124-14:35:36,940 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190124-14:35:36,960 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 190124-14:35:37,1 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 190124-14:35:37,14 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 190124-14:35:38,643 nipype.workflow INFO:
# 	 [Job 0] Completed (l1analysis.selectfiles).
# 190124-14:35:38,646 nipype.workflow INFO:
# 	 [Job 10] Completed (l1analysis.selectfiles).
# 190124-14:35:38,649 nipype.workflow INFO:
# 	 [Job 20] Completed (l1analysis.selectfiles).
# 190124-14:35:38,652 nipype.workflow INFO:
# 	 [Job 30] Completed (l1analysis.selectfiles).
# 190124-14:35:38,660 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 123 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:35:38,794 nipype.workflow INFO:
# 	 [Job 1] Cached (l1analysis.make_input3).
# 190124-14:35:38,799 nipype.workflow INFO:
# 	 [Job 2] Cached (l1analysis.make_input2).
# 190124-14:35:38,809 nipype.workflow INFO:
# 	 [Job 3] Cached (l1analysis.make_input1).
# 190124-14:35:38,814 nipype.workflow INFO:
# 	 [Job 11] Cached (l1analysis.make_input3).
# 190124-14:35:38,818 nipype.workflow INFO:
# 	 [Job 12] Cached (l1analysis.make_input2).
# 190124-14:35:38,823 nipype.workflow INFO:
# 	 [Job 13] Cached (l1analysis.make_input1).
# 190124-14:35:38,826 nipype.workflow INFO:
# 	 [Job 21] Cached (l1analysis.make_input3).
# 190124-14:35:40,650 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 118 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:35:40,759 nipype.workflow INFO:
# 	 [Job 5] Cached (l1analysis.modelspec).
# 190124-14:35:40,779 nipype.workflow INFO:
# 	 [Job 15] Cached (l1analysis.modelspec).
# 190124-14:35:40,786 nipype.workflow INFO:
# 	 [Job 22] Cached (l1analysis.make_input2).
# 190124-14:35:40,803 nipype.workflow INFO:
# 	 [Job 23] Cached (l1analysis.make_input1).
# 190124-14:35:40,808 nipype.workflow INFO:
# 	 [Job 31] Cached (l1analysis.make_input3).
# 190124-14:35:40,813 nipype.workflow INFO:
# 	 [Job 32] Cached (l1analysis.make_input2).
# 190124-14:35:40,818 nipype.workflow INFO:
# 	 [Job 33] Cached (l1analysis.make_input1).
# 190124-14:35:42,651 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 114 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:35:42,837 nipype.workflow INFO:
# 	 [Job 6] Cached (l1analysis.level1design).
# 190124-14:35:42,908 nipype.workflow INFO:
# 	 [Job 16] Cached (l1analysis.level1design).
# 190124-14:35:42,937 nipype.workflow INFO:
# 	 [Job 25] Cached (l1analysis.modelspec).
# 190124-14:35:42,941 nipype.workflow INFO:
# 	 [Job 34] Cached (l1analysis.getsubjectinfo).
# 190124-14:35:42,949 nipype.workflow INFO:
# 	 [Job 44] Cached (l1analysis.getsubjectinfo).
# 190124-14:35:42,960 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_199/selectfiles".
# 190124-14:35:42,973 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190124-14:35:42,952 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_201/selectfiles".
# 190124-14:35:43,16 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190124-14:35:43,36 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 190124-14:35:43,69 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 190124-14:35:44,646 nipype.workflow INFO:
# 	 [Job 40] Completed (l1analysis.selectfiles).
# 190124-14:35:44,650 nipype.workflow INFO:
# 	 [Job 50] Completed (l1analysis.selectfiles).
# 190124-14:35:44,660 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 117 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:35:44,803 nipype.workflow INFO:
# 	 [Job 7] Cached (l1analysis.level1estimate).
# 190124-14:35:44,822 nipype.workflow INFO:
# 	 [Job 17] Cached (l1analysis.level1estimate).
# 190124-14:35:44,917 nipype.workflow INFO:
# 	 [Job 26] Cached (l1analysis.level1design).
# 190124-14:35:44,953 nipype.workflow INFO:
# 	 [Job 35] Cached (l1analysis.modelspec).
# 190124-14:35:44,960 nipype.workflow INFO:
# 	 [Job 41] Cached (l1analysis.make_input3).
# 190124-14:35:44,966 nipype.workflow INFO:
# 	 [Job 42] Cached (l1analysis.make_input2).
# 190124-14:35:44,972 nipype.workflow INFO:
# 	 [Job 43] Cached (l1analysis.make_input1).
# 190124-14:35:46,655 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 115 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:35:46,796 nipype.workflow INFO:
# 	 [Job 8] Cached (l1analysis.level1conest).
# 190124-14:35:46,824 nipype.workflow INFO:
# 	 [Job 18] Cached (l1analysis.level1conest).
# 190124-14:35:46,839 nipype.workflow INFO:
# 	 [Job 27] Cached (l1analysis.level1estimate).
# 190124-14:35:46,906 nipype.workflow INFO:
# 	 [Job 36] Cached (l1analysis.level1design).
# 190124-14:35:46,945 nipype.workflow INFO:
# 	 [Job 45] Cached (l1analysis.modelspec).
# 190124-14:35:46,950 nipype.workflow INFO:
# 	 [Job 51] Cached (l1analysis.make_input3).
# 190124-14:35:46,956 nipype.workflow INFO:
# 	 [Job 52] Cached (l1analysis.make_input2).
# 190124-14:35:48,657 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 113 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:35:48,782 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_212/datasink".
# 190124-14:35:48,804 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190124-14:35:48,811 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/mask.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/mask.nii
# 190124-14:35:48,820 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_209/datasink".
# 190124-14:35:48,844 nipype.workflow INFO:
# 	 [Job 28] Cached (l1analysis.level1conest).
# 190124-14:35:48,852 nipype.workflow INFO:
# 	 [Job 37] Cached (l1analysis.level1estimate).
# 190124-14:35:48,877 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190124-14:35:48,882 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/mask.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/mask.nii
# 190124-14:35:48,923 nipype.workflow INFO:
# 	 [Job 46] Cached (l1analysis.level1design).
# 190124-14:35:48,929 nipype.workflow INFO:
# 	 [Job 53] Cached (l1analysis.make_input1).
# 190124-14:35:48,933 nipype.workflow INFO:
# 	 [Job 54] Cached (l1analysis.getsubjectinfo).
# 190124-14:35:49,231 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/SPM.mat -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/SPM.mat
# 190124-14:35:49,235 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmT_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmT_0001.nii
# 190124-14:35:49,238 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmT_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmT_0002.nii
# 190124-14:35:49,241 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmT_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmT_0003.nii
# 190124-14:35:49,244 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmT_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmT_0004.nii
# 190124-14:35:49,247 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmT_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmT_0005.nii
# 190124-14:35:49,250 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmT_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmT_0006.nii
# 190124-14:35:49,253 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmT_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmT_0007.nii
# 190124-14:35:49,256 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmT_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmT_0008.nii
# 190124-14:35:49,258 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmT_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmT_0009.nii
# 190124-14:35:49,261 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmT_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmT_0010.nii
# 190124-14:35:49,263 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmF_0011.nii
# 190124-14:35:49,266 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmF_0012.nii
# 190124-14:35:49,268 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/con_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0001.nii
# 190124-14:35:49,271 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/con_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0002.nii
# 190124-14:35:49,273 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/con_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0003.nii
# 190124-14:35:49,276 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/con_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0004.nii
# 190124-14:35:49,278 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/con_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0005.nii
# 190124-14:35:49,280 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/con_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0006.nii
# 190124-14:35:49,282 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/con_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0007.nii
# 190124-14:35:49,284 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/con_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0008.nii
# 190124-14:35:49,287 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/con_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0009.nii
# 190124-14:35:49,289 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/con_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0010.nii
# 190124-14:35:49,291 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/ess_0011.nii
# 190124-14:35:49,293 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/ess_0012.nii
# 190124-14:35:49,295 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmF_0011.nii
# 190124-14:35:49,297 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/spmF_0012.nii
# 190124-14:35:49,299 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/ess_0011.nii
# 190124-14:35:49,300 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_212/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/ess_0012.nii
# 190124-14:35:49,312 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 190124-14:35:49,320 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/SPM.mat -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/SPM.mat
# 190124-14:35:49,324 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmT_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmT_0001.nii
# 190124-14:35:49,326 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmT_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmT_0002.nii
# 190124-14:35:49,329 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmT_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmT_0003.nii
# 190124-14:35:49,332 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmT_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmT_0004.nii
# 190124-14:35:49,334 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmT_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmT_0005.nii
# 190124-14:35:49,337 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmT_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmT_0006.nii
# 190124-14:35:49,339 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmT_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmT_0007.nii
# 190124-14:35:49,342 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmT_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmT_0008.nii
# 190124-14:35:49,344 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmT_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmT_0009.nii
# 190124-14:35:49,346 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmT_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmT_0010.nii
# 190124-14:35:49,349 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmF_0011.nii
# 190124-14:35:49,351 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmF_0012.nii
# 190124-14:35:49,354 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/con_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/con_0001.nii
# 190124-14:35:49,356 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/con_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/con_0002.nii
# 190124-14:35:49,358 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/con_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/con_0003.nii
# 190124-14:35:49,360 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/con_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/con_0004.nii
# 190124-14:35:49,362 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/con_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/con_0005.nii
# 190124-14:35:49,365 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/con_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/con_0006.nii
# 190124-14:35:49,367 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/con_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/con_0007.nii
# 190124-14:35:49,369 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/con_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/con_0008.nii
# 190124-14:35:49,371 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/con_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/con_0009.nii
# 190124-14:35:49,373 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/con_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/con_0010.nii
# 190124-14:35:49,375 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/ess_0011.nii
# 190124-14:35:49,377 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/ess_0012.nii
# 190124-14:35:49,379 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmF_0011.nii
# 190124-14:35:49,381 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/spmF_0012.nii
# 190124-14:35:49,383 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/ess_0011.nii
# 190124-14:35:49,385 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_209/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/ess_0012.nii
# 190124-14:35:49,394 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 190124-14:35:50,654 nipype.workflow INFO:
# 	 [Job 9] Completed (l1analysis.datasink).
# 190124-14:35:50,658 nipype.workflow INFO:
# 	 [Job 19] Completed (l1analysis.datasink).
# 190124-14:35:50,666 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 110 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:35:50,825 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_206/datasink".
# 190124-14:35:50,839 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190124-14:35:50,844 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/mask.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/mask.nii
# 190124-14:35:50,853 nipype.workflow INFO:
# 	 [Job 38] Cached (l1analysis.level1conest).
# 190124-14:35:50,878 nipype.workflow INFO:
# 	 [Job 47] Cached (l1analysis.level1estimate).
# 190124-14:35:50,964 nipype.workflow INFO:
# 	 [Job 55] Cached (l1analysis.modelspec).
# 190124-14:35:50,988 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_193/selectfiles".
# 190124-14:35:51,0 nipype.workflow INFO:
# 	 [Job 64] Cached (l1analysis.getsubjectinfo).
# 190124-14:35:51,6 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190124-14:35:51,23 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_190/selectfiles".
# 190124-14:35:51,30 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190124-14:35:51,71 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 190124-14:35:51,78 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 190124-14:35:51,202 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/SPM.mat -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/SPM.mat
# 190124-14:35:51,206 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmT_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmT_0001.nii
# 190124-14:35:51,208 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmT_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmT_0002.nii
# 190124-14:35:51,211 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmT_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmT_0003.nii
# 190124-14:35:51,213 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmT_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmT_0004.nii
# 190124-14:35:51,215 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmT_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmT_0005.nii
# 190124-14:35:51,217 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmT_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmT_0006.nii
# 190124-14:35:51,218 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmT_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmT_0007.nii
# 190124-14:35:51,220 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmT_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmT_0008.nii
# 190124-14:35:51,221 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmT_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmT_0009.nii
# 190124-14:35:51,223 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmT_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmT_0010.nii
# 190124-14:35:51,225 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmF_0011.nii
# 190124-14:35:51,226 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmF_0012.nii
# 190124-14:35:51,228 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/con_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/con_0001.nii
# 190124-14:35:51,229 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/con_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/con_0002.nii
# 190124-14:35:51,231 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/con_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/con_0003.nii
# 190124-14:35:51,232 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/con_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/con_0004.nii
# 190124-14:35:51,234 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/con_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/con_0005.nii
# 190124-14:35:51,235 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/con_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/con_0006.nii
# 190124-14:35:51,237 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/con_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/con_0007.nii
# 190124-14:35:51,239 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/con_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/con_0008.nii
# 190124-14:35:51,241 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/con_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/con_0009.nii
# 190124-14:35:51,243 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/con_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/con_0010.nii
# 190124-14:35:51,245 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/ess_0011.nii
# 190124-14:35:51,247 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/ess_0012.nii
# 190124-14:35:51,249 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmF_0011.nii
# 190124-14:35:51,251 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/spmF_0012.nii
# 190124-14:35:51,253 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/ess_0011.nii
# 190124-14:35:51,255 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_206/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-206/fwhm-8/ess_0012.nii
# 190124-14:35:51,265 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 190124-14:35:52,656 nipype.workflow INFO:
# 	 [Job 29] Completed (l1analysis.datasink).
# 190124-14:35:52,659 nipype.workflow INFO:
# 	 [Job 60] Completed (l1analysis.selectfiles).
# 190124-14:35:52,662 nipype.workflow INFO:
# 	 [Job 70] Completed (l1analysis.selectfiles).
# 190124-14:35:52,668 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 112 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:35:52,845 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_205/datasink".
# 190124-14:35:52,857 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190124-14:35:52,861 nipype.workflow INFO:
# 	 [Job 48] Cached (l1analysis.level1conest).
# 190124-14:35:52,860 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/mask.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/mask.nii
# 190124-14:35:53,119 nipype.workflow INFO:
# 	 [Job 56] Cached (l1analysis.level1design).
# 190124-14:35:53,127 nipype.workflow INFO:
# 	 [Job 61] Cached (l1analysis.make_input3).
# 190124-14:35:53,134 nipype.workflow INFO:
# 	 [Job 62] Cached (l1analysis.make_input2).
# 190124-14:35:53,178 nipype.workflow INFO:
# 	 [Job 63] Cached (l1analysis.make_input1).
# 190124-14:35:53,209 nipype.workflow INFO:
# 	 [Job 71] Cached (l1analysis.make_input3).
# 190124-14:35:53,523 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/SPM.mat -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/SPM.mat
# 190124-14:35:53,526 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmT_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmT_0001.nii
# 190124-14:35:53,529 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmT_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmT_0002.nii
# 190124-14:35:53,532 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmT_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmT_0003.nii
# 190124-14:35:53,536 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmT_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmT_0004.nii
# 190124-14:35:53,540 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmT_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmT_0005.nii
# 190124-14:35:53,543 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmT_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmT_0006.nii
# 190124-14:35:53,547 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmT_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmT_0007.nii
# 190124-14:35:53,549 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmT_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmT_0008.nii
# 190124-14:35:53,552 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmT_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmT_0009.nii
# 190124-14:35:53,554 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmT_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmT_0010.nii
# 190124-14:35:53,557 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmF_0011.nii
# 190124-14:35:53,560 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmF_0012.nii
# 190124-14:35:53,563 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/con_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/con_0001.nii
# 190124-14:35:53,566 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/con_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/con_0002.nii
# 190124-14:35:53,569 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/con_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/con_0003.nii
# 190124-14:35:53,571 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/con_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/con_0004.nii
# 190124-14:35:53,574 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/con_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/con_0005.nii
# 190124-14:35:53,576 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/con_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/con_0006.nii
# 190124-14:35:53,578 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/con_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/con_0007.nii
# 190124-14:35:53,580 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/con_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/con_0008.nii
# 190124-14:35:53,583 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/con_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/con_0009.nii
# 190124-14:35:53,586 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/con_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/con_0010.nii
# 190124-14:35:53,588 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/ess_0011.nii
# 190124-14:35:53,590 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/ess_0012.nii
# 190124-14:35:53,593 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmF_0011.nii
# 190124-14:35:53,595 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/spmF_0012.nii
# 190124-14:35:53,598 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/ess_0011.nii
# 190124-14:35:53,601 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_205/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-205/fwhm-8/ess_0012.nii
# 190124-14:35:53,613 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 190124-14:35:54,657 nipype.workflow INFO:
# 	 [Job 39] Completed (l1analysis.datasink).
# 190124-14:35:54,664 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 108 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:35:54,771 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_201/datasink".
# 190124-14:35:54,784 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190124-14:35:54,790 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/mask.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/mask.nii
# 190124-14:35:54,795 nipype.workflow INFO:
# 	 [Job 57] Cached (l1analysis.level1estimate).
# 190124-14:35:54,837 nipype.workflow INFO:
# 	 [Job 65] Cached (l1analysis.modelspec).
# 190124-14:35:54,850 nipype.workflow INFO:
# 	 [Job 72] Cached (l1analysis.make_input2).
# 190124-14:35:54,857 nipype.workflow INFO:
# 	 [Job 73] Cached (l1analysis.make_input1).
# 190124-14:35:54,867 nipype.workflow INFO:
# 	 [Job 74] Cached (l1analysis.getsubjectinfo).
# 190124-14:35:54,874 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_183/selectfiles".
# 190124-14:35:54,880 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190124-14:35:54,914 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 190124-14:35:55,16 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/SPM.mat -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/SPM.mat
# 190124-14:35:55,19 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmT_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmT_0001.nii
# 190124-14:35:55,21 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmT_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmT_0002.nii
# 190124-14:35:55,23 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmT_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmT_0003.nii
# 190124-14:35:55,25 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmT_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmT_0004.nii
# 190124-14:35:55,27 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmT_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmT_0005.nii
# 190124-14:35:55,29 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmT_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmT_0006.nii
# 190124-14:35:55,31 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmT_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmT_0007.nii
# 190124-14:35:55,33 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmT_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmT_0008.nii
# 190124-14:35:55,34 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmT_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmT_0009.nii
# 190124-14:35:55,36 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmT_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmT_0010.nii
# 190124-14:35:55,38 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmF_0011.nii
# 190124-14:35:55,39 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmF_0012.nii
# 190124-14:35:55,41 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/con_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/con_0001.nii
# 190124-14:35:55,42 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/con_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/con_0002.nii
# 190124-14:35:55,44 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/con_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/con_0003.nii
# 190124-14:35:55,46 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/con_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/con_0004.nii
# 190124-14:35:55,48 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/con_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/con_0005.nii
# 190124-14:35:55,49 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/con_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/con_0006.nii
# 190124-14:35:55,51 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/con_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/con_0007.nii
# 190124-14:35:55,53 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/con_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/con_0008.nii
# 190124-14:35:55,56 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/con_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/con_0009.nii
# 190124-14:35:55,58 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/con_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/con_0010.nii
# 190124-14:35:55,60 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/ess_0011.nii
# 190124-14:35:55,62 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/ess_0012.nii
# 190124-14:35:55,64 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmF_0011.nii
# 190124-14:35:55,67 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/spmF_0012.nii
# 190124-14:35:55,70 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/ess_0011.nii
# 190124-14:35:55,72 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_201/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-201/fwhm-8/ess_0012.nii
# 190124-14:35:55,84 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 190124-14:35:56,659 nipype.workflow INFO:
# 	 [Job 49] Completed (l1analysis.datasink).
# 190124-14:35:56,664 nipype.workflow INFO:
# 	 [Job 80] Completed (l1analysis.selectfiles).
# 190124-14:35:56,673 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 107 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:35:56,774 nipype.workflow INFO:
# 	 [Job 58] Cached (l1analysis.level1conest).
# 190124-14:35:56,885 nipype.workflow INFO:
# 	 [Job 66] Cached (l1analysis.level1design).
# 190124-14:35:56,925 nipype.workflow INFO:
# 	 [Job 75] Cached (l1analysis.modelspec).
# 190124-14:35:56,938 nipype.workflow INFO:
# 	 [Job 81] Cached (l1analysis.make_input3).
# 190124-14:35:56,946 nipype.workflow INFO:
# 	 [Job 82] Cached (l1analysis.make_input2).
# 190124-14:35:56,958 nipype.workflow INFO:
# 	 [Job 83] Cached (l1analysis.make_input1).
# 190124-14:35:56,963 nipype.workflow INFO:
# 	 [Job 84] Cached (l1analysis.getsubjectinfo).
# 190124-14:35:58,665 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 104 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:35:58,791 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_199/datasink".
# 190124-14:35:58,806 nipype.workflow INFO:
# 	 [Job 67] Cached (l1analysis.level1estimate).
# 190124-14:35:58,810 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190124-14:35:58,815 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_199/mask.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-199/fwhm-8/mask.nii
# 190124-14:35:58,933 nipype.workflow INFO:
# 	 [Job 76] Cached (l1analysis.level1design).
# 190124-14:35:58,945 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_199/SPM.mat -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-199/fwhm-8/SPM.mat
# 190124-14:35:58,948 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_199/spmT_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-199/fwhm-8/spmT_0001.nii
# 190124-14:35:58,950 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_199/spmT_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-199/fwhm-8/spmT_0002.nii
# 190124-14:35:58,952 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_199/spmT_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-199/fwhm-8/spmT_0003.nii
# 190124-14:35:58,955 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_199/spmT_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-199/fwhm-8/spmT_0004.nii
# 190124-14:35:58,957 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_199/spmT_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-199/fwhm-8/spmT_0005.nii
# 190124-14:35:58,960 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_199/spmT_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-199/fwhm-8/spmT_0006.nii190124-14:35:58,961 nipype.workflow INFO:
# 	 [Job 85] Cached (l1analysis.modelspec).
#
# 190124-14:35:58,962 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_199/spmT_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-199/fwhm-8/spmT_0007.nii
# 190124-14:35:58,965 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_199/spmT_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-199/fwhm-8/spmT_0008.nii
# 190124-14:35:58,967 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_199/spmT_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-199/fwhm-8/spmT_0009.nii
# 190124-14:35:58,970 nipype.interface INFO:
# ...
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_066/con_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-066/fwhm-8/con_0008.nii
# 190124-14:38:25,63 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_066/con_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-066/fwhm-8/con_0009.nii
# 190124-14:38:25,65 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_066/con_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-066/fwhm-8/con_0010.nii
# 190124-14:38:25,67 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_066/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-066/fwhm-8/ess_0011.nii
# 190124-14:38:25,69 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_066/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-066/fwhm-8/ess_0012.nii
# 190124-14:38:25,72 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_066/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-066/fwhm-8/spmF_0011.nii
# 190124-14:38:25,74 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_066/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-066/fwhm-8/spmF_0012.nii
# 190124-14:38:25,76 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_066/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-066/fwhm-8/ess_0011.nii
# 190124-14:38:25,77 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_066/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-066/fwhm-8/ess_0012.nii
# 190124-14:38:25,84 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 190124-14:38:26,782 nipype.workflow INFO:
# 	 [Job 569] Completed (l1analysis.datasink).
# 190124-14:38:26,793 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:38:26,929 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_060/datasink".190124-14:38:26,930 nipype.workflow INFO:
# 	 [Job 587] Cached (l1analysis.level1estimate).
#
# 190124-14:38:26,945 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190124-14:38:26,949 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/mask.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/mask.nii
# 190124-14:38:26,980 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/SPM.mat -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/SPM.mat
# 190124-14:38:26,984 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmT_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmT_0001.nii
# 190124-14:38:26,987 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmT_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmT_0002.nii
# 190124-14:38:26,989 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmT_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmT_0003.nii
# 190124-14:38:26,994 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmT_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmT_0004.nii
# 190124-14:38:26,996 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmT_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmT_0005.nii
# 190124-14:38:26,999 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmT_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmT_0006.nii
# 190124-14:38:27,1 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmT_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmT_0007.nii
# 190124-14:38:27,4 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmT_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmT_0008.nii
# 190124-14:38:27,6 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmT_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmT_0009.nii
# 190124-14:38:27,8 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmT_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmT_0010.nii
# 190124-14:38:27,10 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmF_0011.nii
# 190124-14:38:27,12 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmF_0012.nii
# 190124-14:38:27,15 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/con_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/con_0001.nii
# 190124-14:38:27,17 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/con_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/con_0002.nii
# 190124-14:38:27,19 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/con_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/con_0003.nii
# 190124-14:38:27,21 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/con_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/con_0004.nii
# 190124-14:38:27,23 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/con_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/con_0005.nii
# 190124-14:38:27,25 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/con_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/con_0006.nii
# 190124-14:38:27,27 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/con_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/con_0007.nii
# 190124-14:38:27,29 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/con_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/con_0008.nii
# 190124-14:38:27,31 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/con_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/con_0009.nii
# 190124-14:38:27,33 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/con_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/con_0010.nii
# 190124-14:38:27,36 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/ess_0011.nii
# 190124-14:38:27,38 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/ess_0012.nii
# 190124-14:38:27,40 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmF_0011.nii
# 190124-14:38:27,42 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/spmF_0012.nii
# 190124-14:38:27,44 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/ess_0011.nii
# 190124-14:38:27,46 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_060/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-060/fwhm-8/ess_0012.nii
# 190124-14:38:27,55 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 190124-14:38:28,787 nipype.workflow INFO:
# 	 [Job 579] Completed (l1analysis.datasink).
# 190124-14:38:28,797 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.
# 190124-14:38:28,964 nipype.workflow INFO:
# 	 [Job 588] Cached (l1analysis.level1conest).
# 190124-14:38:30,911 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/data/EFAT/EFAT_output/PT/workingdir/l1analysis/_fwhm_id_8_subject_id_058/datasink".
# 190124-14:38:30,927 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190124-14:38:30,931 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/mask.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/mask.nii
# 190124-14:38:30,966 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/SPM.mat -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/SPM.mat
# 190124-14:38:30,969 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmT_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmT_0001.nii
# 190124-14:38:30,971 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmT_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmT_0002.nii
# 190124-14:38:30,973 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmT_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmT_0003.nii
# 190124-14:38:30,975 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmT_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmT_0004.nii
# 190124-14:38:30,977 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmT_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmT_0005.nii
# 190124-14:38:30,979 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmT_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmT_0006.nii
# 190124-14:38:30,981 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmT_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmT_0007.nii
# 190124-14:38:30,983 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmT_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmT_0008.nii
# 190124-14:38:30,985 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmT_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmT_0009.nii
# 190124-14:38:30,987 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmT_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmT_0010.nii
# 190124-14:38:30,988 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmF_0011.nii
# 190124-14:38:30,990 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmF_0012.nii
# 190124-14:38:30,992 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/con_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/con_0001.nii
# 190124-14:38:30,994 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/con_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/con_0002.nii
# 190124-14:38:30,995 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/con_0003.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/con_0003.nii
# 190124-14:38:30,997 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/con_0004.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/con_0004.nii
# 190124-14:38:30,999 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/con_0005.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/con_0005.nii
# 190124-14:38:31,1 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/con_0006.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/con_0006.nii
# 190124-14:38:31,3 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/con_0007.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/con_0007.nii
# 190124-14:38:31,5 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/con_0008.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/con_0008.nii
# 190124-14:38:31,9 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/con_0009.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/con_0009.nii
# 190124-14:38:31,11 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/con_0010.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/con_0010.nii
# 190124-14:38:31,14 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/ess_0011.nii
# 190124-14:38:31,16 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/ess_0012.nii
# 190124-14:38:31,19 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmF_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmF_0011.nii
# 190124-14:38:31,21 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/spmF_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/spmF_0012.nii
# 190124-14:38:31,24 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/ess_0011.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/ess_0011.nii
# 190124-14:38:31,26 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/1stLevel/_fwhm_id_8_subject_id_058/ess_0012.nii -> /data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/ess_0012.nii
# 190124-14:38:31,37 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 190124-14:38:32,788 nipype.workflow INFO:
# 	 [Job 589] Completed (l1analysis.datasink).
# 190124-14:38:32,797 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 7/7.

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %%
from scipy.io import loadmat

# Using scipy's loadmat function we can access SPM.mat
spmmat = loadmat('/data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-058/fwhm-8/SPM.mat',
                 struct_as_record=False)

# %%
designMatrix = spmmat['SPM'][0][0].xX[0][0].X
names = [i[0] for i in spmmat['SPM'][0][0].xX[0][0].name[0]]

# %%
normed_design = designMatrix / np.abs(designMatrix).max(axis=0)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
plt.imshow(normed_design, aspect='auto', cmap='gray', interpolation='none')
ax.set_ylabel('Volume id')
ax.set_xticks(np.arange(len(names)))
ax.set_xticklabels(names, rotation=90);

# %%
from nilearn.plotting import plot_stat_map
anatimg = '/home/soyeon/mni_icbm152_nlin_asym_09c/1mm_T1.nii.gz'

# %%
plot_stat_map(
    '/data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-209/fwhm-8/con_0001.nii', title='average - fwhm=8',
    bg_img=anatimg, threshold=2, display_mode='y', cut_coords=(-5, 0, 5, 10, 15), dim=-1);

# %%
plot_stat_map(
    '/data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0002.nii', title='angry - fwhm=8',
    bg_img=anatimg, threshold=2, display_mode='y', cut_coords=(-5, 0, 5, 10, 15), dim=-1);

# %%
plot_stat_map(
    '/data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0003.nii', title='fear - fwhm=8',
    bg_img=anatimg, threshold=1e-06, display_mode='y', cut_coords=(-5, 0, 5, 10, 15), dim=-1);

# %%
plot_stat_map(
    '/data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0004.nii', title='happy - fwhm=8',
    bg_img=anatimg, threshold=1e-06, display_mode='y', cut_coords=(-5, 0, 5, 10, 15), dim=-1);

# %%
plot_stat_map(
    '/data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0004.nii', title='happy - fwhm=8',
    bg_img=anatimg, threshold=1e-06, display_mode='y', cut_coords=(-5, 0, 5, 10, 15), dim=-1);

# %%
plot_stat_map(
    '/data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0005.nii', title='sad - fwhm=8',
    bg_img=anatimg, threshold=1e-06, display_mode='y', cut_coords=(-5, 0, 5, 10, 15), dim=-1);

# %%
plot_stat_map(
    '/data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0006.nii', title='shapes - fwhm=8',
    bg_img=anatimg, threshold=1e-06, display_mode='y', cut_coords=(-5, 0, 5, 10, 15), dim=-1);

# %%
plot_stat_map(
    '/data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-089/fwhm-8/con_0007.nii', title='angry>shapes - fwhm=8',
    bg_img=anatimg, threshold=2, display_mode='z', cut_coords=(-5, 0, 5, 10, 15), dim=-1);

# %%
plot_stat_map(
    '/data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0008.nii', title='fear>shapes - fwhm=8',
    bg_img=anatimg, threshold=1e-06, display_mode='y', cut_coords=(-5, 0, 5, 10, 15), dim=-1);

# %%
plot_stat_map(
    '/data/EFAT/EFAT_output/PT/datasink/1stLevel/sub-212/fwhm-8/con_0009.nii', title='happy>shapes - fwhm=8',
    bg_img=anatimg, threshold=1e-06, display_mode='y', cut_coords=(-5, 0, 5, 10, 15), dim=-1);
