# %%
from nilearn import plotting
# %matplotlib inline
from os.path import join as opj
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.interfaces.spm import (MultipleRegressionDesign, EstimateModel,
                                   EstimateContrast, Threshold)
from nipype.interfaces.utility import IdentityInterface
from nipype import Workflow, Node
from nipype.interfaces.fsl import Info
from nipype.algorithms.misc import Gunzip
# Out:
# /home/soyeon/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('/opt/spm12')

# %%
experiment_dir = '/data/EFAT/EFAT_output/PT'
output_dir = 'datasink'
working_dir = 'workingdir'

fwhm = [8]

contrast_list = ['con_0001', 'con_0002', 'con_0003', 'con_0004', 'con_0005', 
                 'con_0006', 'con_0007', 'con_0008', 'con_0009', 'con_0010']

mask = "/home/soyeon/mni_icbm152_nlin_asym_09c/1mm_brainmask.nii.gz"

# %%
import pandas as pd

hama = pd.read_excel('/data/EFAT/info/HAMA_PT_2.xlsx')
hamd = pd.read_excel('/data/EFAT/info/HAMD_PT_2.xlsx')
age = pd.read_excel('/data/EFAT/info/Age_2.xlsx')
edu = pd.read_excel('/data/EFAT/info/Education_2.xlsx')
gender = pd.read_excel('/data/EFAT/info/Gender_2.xlsx')

# %%
HAM_A = hama['vector'].values.tolist()
HAM_D = hamd['vector'].values.tolist()
Age = age['Age'].values.tolist()
Edu = edu['Education in years'].values.tolist()
Gender = gender['Gender (Male = 1, Female = 2)'].values.tolist()

# %%
# Gunzip - unzip the mask image
gunzip = Node(Gunzip(in_file=mask), name="gunzip")

# Multipleregression - creates Multiple Regression Design
multipleregression = Node(MultipleRegressionDesign(),
                         name="multipleregression")

multipleregression.inputs.covariates = [dict(vector=HAM_A, name='HAM_A'),
                                        dict(vector=HAM_D, name='HAM_D'),
                                        dict(vector=Age, name='Age'),
                                        dict(vector=Edu, name='Education'),
                                        dict(vector=Gender, name='Gender')]

# EstimateModel - estimates the model
level2estimate = Node(EstimateModel(estimation_method={'Classical': 1}),
                      name="level2estimate")

# EstimateContrast - estimates group contrast
level2conestimate = Node(EstimateContrast(group_contrast=True),
                         name="level2conestimate")
cont1 = ['HAM_A', 'T', ['HAM_A', 'HAM_D', 'Age', 'Education', 'Gender'], [1, -0.25, -0.25, -0.25, -0.25]]
cont2 = ['HAM_D', 'T', ['HAM_A', 'HAM_D', 'Age', 'Education', 'Gender'], [0.25, -1, 0.25, 0.25, 0.25]]
level2conestimate.inputs.contrasts = [cont1, cont2]

# %%
# Infosource - a function free node to iterate over the list of subject names# Infos 
infosource = Node(IdentityInterface(fields=['contrast_id', 'fwhm_id']),
                  name="infosource")
infosource.iterables = [('contrast_id', contrast_list),
                        ('fwhm_id', fwhm)]

# Change the SelectFiles template and recreate the node
templates = {'cons': opj(output_dir, '1stLevel', 'sub-*', 'fwhm-{fwhm_id}',
                         '{contrast_id}.nii')}
selectfiles = Node(SelectFiles(templates,
                               base_directory=experiment_dir,
                               sort_filelist=True),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

# Change the substituion parameters for the datasink
substitutions = [('_contrast_id_', '')]
subjFolders = [('%s_fwhm_id_%s' % (con, f), 'spm_%s_fwhm%s' % (con, f))
               for f in fwhm
               for con in contrast_list]
substitutions.extend(subjFolders)
datasink.inputs.substitutions = substitutions

# %%
# Initiation of the 2nd-level analysis workflow
l2analysis = Workflow(name='spm_l2analysis')
l2analysis.base_dir = opj(experiment_dir, working_dir)

# Connect up the 2nd-level analysis components
l2analysis.connect([(infosource, selectfiles, [('contrast_id', 'contrast_id'),
                                               ('fwhm_id', 'fwhm_id')]),
                    (selectfiles, multipleregression, [('cons', 'in_files')]),
                    (gunzip, multipleregression, [('out_file',
                                                  'explicit_mask_file')]),
                    (multipleregression, level2estimate, [('spm_mat_file',
                                                          'spm_mat_file')]),
                    (level2estimate, level2conestimate, [('spm_mat_file',
                                                          'spm_mat_file'),
                                                         ('beta_images',
                                                          'beta_images'),
                                                         ('residual_image',
                                                          'residual_image')]),
                    (level2conestimate, datasink, [('spm_mat_file',
                                                    '2ndLevel.@spm_mat'),
                                                   ('spmT_images',
                                                    '2ndLevel.@T'),
                                                   ('con_images',
                                                    '2ndLevel.@con')]),
                    ])

# %%
# Create 1st-level analysis output graph
l2analysis.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=opj(l2analysis.base_dir, 'spm_l2analysis', 'graph.png'))
# Out:
# 190126-17:40:16,278 nipype.workflow INFO:
# 	 Generated workflow graph: /data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/graph.png (graph2use=colored, simple_form=True).

# %%
l2analysis.run('MultiProc', plugin_args={'n_procs': 2})
# Out:
# 190126-17:40:16,595 nipype.workflow INFO:
# 	 Workflow spm_l2analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 190126-17:40:16,894 nipype.workflow INFO:
# 	 Running in parallel.
# 190126-17:40:16,906 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 11 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 2/2.
# 190126-17:40:17,70 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0010_fwhm_id_8/selectfiles".
# 190126-17:40:17,73 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0009_fwhm_id_8/selectfiles".
# 190126-17:40:17,92 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")190126-17:40:17,92 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 190126-17:40:17,784 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.selectfiles".190126-17:40:17,784 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.selectfiles".
#
# 190126-17:40:18,908 nipype.workflow INFO:
# 	 [Job 0] Completed (spm_l2analysis.selectfiles).
# 190126-17:40:18,913 nipype.workflow INFO:
# 	 [Job 1] Completed (spm_l2analysis.selectfiles).
# 190126-17:40:18,917 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 9 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 2/2.
# 190126-17:40:19,56 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0008_fwhm_id_8/selectfiles".
# 190126-17:40:19,58 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0007_fwhm_id_8/selectfiles".
# 190126-17:40:19,63 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190126-17:40:19,65 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190126-17:40:19,83 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.selectfiles".
# 190126-17:40:19,101 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.selectfiles".
# 190126-17:40:20,908 nipype.workflow INFO:
# 	 [Job 2] Completed (spm_l2analysis.selectfiles).
# 190126-17:40:20,911 nipype.workflow INFO:
# 	 [Job 3] Completed (spm_l2analysis.selectfiles).
# 190126-17:40:20,915 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 7 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 2/2.
# 190126-17:40:21,14 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0006_fwhm_id_8/selectfiles".
# 190126-17:40:21,16 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0005_fwhm_id_8/selectfiles".
# 190126-17:40:21,21 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190126-17:40:21,23 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190126-17:40:21,41 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.selectfiles".
# 190126-17:40:21,55 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.selectfiles".
# 190126-17:40:22,911 nipype.workflow INFO:
# 	 [Job 4] Completed (spm_l2analysis.selectfiles).
# 190126-17:40:22,914 nipype.workflow INFO:
# 	 [Job 5] Completed (spm_l2analysis.selectfiles).
# 190126-17:40:22,919 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 2/2.
# 190126-17:40:23,52 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0003_fwhm_id_8/selectfiles".190126-17:40:23,51 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0004_fwhm_id_8/selectfiles".
#
# 190126-17:40:23,59 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")190126-17:40:23,60 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 190126-17:40:23,80 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.selectfiles".
# 190126-17:40:23,82 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.selectfiles".
# 190126-17:40:24,912 nipype.workflow INFO:
# 	 [Job 6] Completed (spm_l2analysis.selectfiles).
# 190126-17:40:24,915 nipype.workflow INFO:
# 	 [Job 7] Completed (spm_l2analysis.selectfiles).
# 190126-17:40:24,920 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 2/2.
# 190126-17:40:25,32 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0002_fwhm_id_8/selectfiles".190126-17:40:25,33 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.selectfiles" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0001_fwhm_id_8/selectfiles".
#
# 190126-17:40:25,37 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190126-17:40:25,39 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190126-17:40:25,61 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.selectfiles".
# 190126-17:40:25,66 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.selectfiles".
# 190126-17:40:26,914 nipype.workflow INFO:
# 	 [Job 8] Completed (spm_l2analysis.selectfiles).
# 190126-17:40:26,918 nipype.workflow INFO:
# 	 [Job 9] Completed (spm_l2analysis.selectfiles).
# 190126-17:40:26,922 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 2/2.
# 190126-17:40:27,18 nipype.workflow INFO:
# 	 [Job 10] Cached (spm_l2analysis.gunzip).
# 190126-17:40:28,918 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 10 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 2/2.
# 190126-17:40:29,25 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.multipleregression".
# 190126-17:40:29,37 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.multipleregression" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0010_fwhm_id_8/multipleregression".
# 190126-17:40:29,40 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.multipleregression".
# 190126-17:40:29,47 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.multipleregression".
# 190126-17:40:29,55 nipype.workflow INFO:
# 	 [Node] Running "multipleregression" ("nipype.interfaces.spm.model.MultipleRegressionDesign")190126-17:40:29,56 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.multipleregression" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0009_fwhm_id_8/multipleregression".
#
# 190126-17:40:29,58 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.multipleregression".
# 190126-17:40:29,75 nipype.workflow INFO:
# 	 [Node] Running "multipleregression" ("nipype.interfaces.spm.model.MultipleRegressionDesign")
# 190126-17:40:30,920 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 8 jobs ready. Free memory (GB): 112.82/113.22, Free processors: 0/2.
#                      Currently running:
#                        * spm_l2analysis.multipleregression
#                        * spm_l2analysis.multipleregression
# 190126-17:41:03,109 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.multipleregression".
# 190126-17:41:03,899 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.multipleregression".
# 190126-17:41:04,954 nipype.workflow INFO:
# 	 [Job 11] Completed (spm_l2analysis.multipleregression).
# 190126-17:41:04,957 nipype.workflow INFO:
# 	 [Job 15] Completed (spm_l2analysis.multipleregression).
# 190126-17:41:04,962 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 10 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 2/2.
# 190126-17:41:05,69 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:41:05,77 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:41:05,76 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.level2estimate" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0010_fwhm_id_8/level2estimate".
# 190126-17:41:05,80 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:41:05,81 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.level2estimate" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0009_fwhm_id_8/level2estimate".
# 190126-17:41:05,84 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:41:05,138 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 190126-17:41:05,149 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 190126-17:41:06,957 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 8 jobs ready. Free memory (GB): 112.82/113.22, Free processors: 0/2.
#                      Currently running:
#                        * spm_l2analysis.level2estimate
#                        * spm_l2analysis.level2estimate
# 190126-17:42:21,710 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.level
nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190126-17:45:01,300 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.multipleregression" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0006_fwhm_id_8/multipleregression".
# 190126-17:45:01,302 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0007_fwhm_id_8/SPM.mat -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0007_fwhm8/SPM.mat190126-17:45:01,303 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.multipleregression".
#
# 190126-17:45:01,317 nipype.workflow INFO:
# 	 [Node] Running "multipleregression" ("nipype.interfaces.spm.model.MultipleRegressionDesign")
# 190126-17:45:01,375 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0007_fwhm_id_8/spmT_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0007_fwhm8/spmT_0001.nii
# 190126-17:45:01,540 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0007_fwhm_id_8/spmT_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0007_fwhm8/spmT_0002.nii
# 190126-17:45:01,711 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0007_fwhm_id_8/con_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0007_fwhm8/con_0001.nii
# 190126-17:45:01,817 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0007_fwhm_id_8/con_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0007_fwhm8/con_0002.nii
# 190126-17:45:01,997 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.datasink".
# 190126-17:45:03,172 nipype.workflow INFO:
# 	 [Job 26] Completed (spm_l2analysis.datasink).
# 190126-17:45:03,177 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.multipleregression
# 190126-17:45:03,308 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.multipleregression".
# 190126-17:45:03,319 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.multipleregression" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0005_fwhm_id_8/multipleregression".
# 190126-17:45:03,322 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.multipleregression".
# 190126-17:45:03,340 nipype.workflow INFO:
# 	 [Node] Running "multipleregression" ("nipype.interfaces.spm.model.MultipleRegressionDesign")
# 190126-17:45:05,176 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 112.82/113.22, Free processors: 0/2.
#                      Currently running:
#                        * spm_l2analysis.multipleregression
#                        * spm_l2analysis.multipleregression
# 190126-17:45:24,432 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.multipleregression".
# 190126-17:45:25,193 nipype.workflow INFO:
# 	 [Job 27] Completed (spm_l2analysis.multipleregression).
# 190126-17:45:25,199 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.multipleregression
# 190126-17:45:25,307 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:45:25,311 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.level2estimate" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0006_fwhm_id_8/level2estimate".
# 190126-17:45:25,315 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:45:25,366 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 190126-17:45:26,654 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.multipleregression".
# 190126-17:45:27,196 nipype.workflow INFO:
# 	 [Job 31] Completed (spm_l2analysis.multipleregression).
# 190126-17:45:27,201 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.level2estimate
# 190126-17:45:27,298 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:45:27,302 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.level2estimate" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0005_fwhm_id_8/level2estimate".
# 190126-17:45:27,305 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:45:27,351 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 190126-17:45:29,199 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 112.82/113.22, Free processors: 0/2.
#                      Currently running:
#                        * spm_l2analysis.level2estimate
#                        * spm_l2analysis.level2estimate
# 190126-17:46:38,452 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.level2estimate".
# 190126-17:46:39,263 nipype.workflow INFO:
# 	 [Job 32] Completed (spm_l2analysis.level2estimate).
# 190126-17:46:39,268 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.level2estimate
# 190126-17:46:39,416 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2conestimate".
# 190126-17:46:39,423 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.level2conestimate" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0005_fwhm_id_8/level2conestimate".
# 190126-17:46:39,426 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2conestimate".
# 190126-17:46:39,445 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 190126-17:46:39,793 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.level2estimate".
# 190126-17:46:41,265 nipype.workflow INFO:
# 	 [Job 28] Completed (spm_l2analysis.level2estimate).
# 190126-17:46:41,269 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.level2conestimate
# 190126-17:46:41,379 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2conestimate".
# 190126-17:46:41,385 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.level2conestimate" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0006_fwhm_id_8/level2conestimate".
# 190126-17:46:41,388 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2conestimate".
# 190126-17:46:41,407 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 190126-17:46:43,268 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 112.82/113.22, Free processors: 0/2.
#                      Currently running:
#                        * spm_l2analysis.level2conestimate
#                        * spm_l2analysis.level2conestimate
# 190126-17:47:04,144 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.level2conestimate".
# 190126-17:47:05,290 nipype.workflow INFO:
# 	 [Job 33] Completed (spm_l2analysis.level2conestimate).
# 190126-17:47:05,294 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.level2conestimate
# 190126-17:47:05,415 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.datasink".
# 190126-17:47:05,424 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.datasink" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0005_fwhm_id_8/datasink".
# 190126-17:47:05,427 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.datasink".
# 190126-17:47:05,438 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190126-17:47:05,443 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0005_fwhm_id_8/SPM.mat -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0005_fwhm8/SPM.mat
# 190126-17:47:05,526 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0005_fwhm_id_8/spmT_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0005_fwhm8/spmT_0001.nii
# 190126-17:47:05,662 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0005_fwhm_id_8/spmT_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0005_fwhm8/spmT_0002.nii
# 190126-17:47:05,806 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0005_fwhm_id_8/con_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0005_fwhm8/con_0001.nii
# 190126-17:47:05,891 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.level2conestimate".
# 190126-17:47:05,945 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0005_fwhm_id_8/con_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0005_fwhm8/con_0002.nii
# 190126-17:47:06,82 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.datasink".
# 190126-17:47:07,291 nipype.workflow INFO:
# 	 [Job 29] Completed (spm_l2analysis.level2conestimate).
# 190126-17:47:07,294 nipype.workflow INFO:
# 	 [Job 34] Completed (spm_l2analysis.datasink).
# 190126-17:47:07,297 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 2/2.
# 190126-17:47:07,407 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.datasink".
# 190126-17:47:07,413 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.datasink" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0006_fwhm_id_8/datasink".
# 190126-17:47:07,416 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.datasink".
# 190126-17:47:07,426 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190126-17:47:07,430 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.multipleregression".
# 190126-17:47:07,431 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0006_fwhm_id_8/SPM.mat -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0006_fwhm8/SPM.mat
# 190126-17:47:07,441 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.multipleregression" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0004_fwhm_id_8/multipleregression".
# 190126-17:47:07,443 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.multipleregression".
# 190126-17:47:07,466 nipype.workflow INFO:
# 	 [Node] Running "multipleregression" ("nipype.interfaces.spm.model.MultipleRegressionDesign")
# 190126-17:47:07,501 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0006_fwhm_id_8/spmT_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0006_fwhm8/spmT_0001.nii
# 190126-17:47:07,651 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0006_fwhm_id_8/spmT_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0006_fwhm8/spmT_0002.nii
# 190126-17:47:07,764 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0006_fwhm_id_8/con_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0006_fwhm8/con_0001.nii
# 190126-17:47:07,924 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0006_fwhm_id_8/con_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0006_fwhm8/con_0002.nii
# 190126-17:47:08,54 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.datasink".
# 190126-17:47:09,294 nipype.workflow INFO:
# 	 [Job 30] Completed (spm_l2analysis.datasink).
# 190126-17:47:09,299 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.multipleregression
# 190126-17:47:09,392 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.multipleregression".
# 190126-17:47:09,400 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.multipleregression" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0003_fwhm_id_8/multipleregression".
# 190126-17:47:09,403 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.multipleregression".
# 190126-17:47:09,421 nipype.workflow INFO:
# 	 [Node] Running "multipleregression" ("nipype.interfaces.spm.model.MultipleRegressionDesign")
# 190126-17:47:11,297 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 112.82/113.22, Free processors: 0/2.
#                      Currently running:
#                        * spm_l2analysis.multipleregression
#                        * spm_l2analysis.multipleregression
# 190126-17:47:30,938 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.multipleregression".
# 190126-17:47:31,316 nipype.workflow INFO:
# 	 [Job 35] Completed (spm_l2analysis.multipleregression).
# 190126-17:47:31,320 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.multipleregression
# 190126-17:47:31,431 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:47:31,436 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.level2estimate" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0004_fwhm_id_8/level2estimate".
# 190126-17:47:31,439 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:47:31,471 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 190126-17:47:32,918 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.multipleregression".
# 190126-17:47:33,318 nipype.workflow INFO:
# 	 [Job 39] Completed (spm_l2analysis.multipleregression).
# 190126-17:47:33,323 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.level2estimate
# 190126-17:47:33,465 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:47:33,469 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.level2estimate" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0003_fwhm_id_8/level2estimate".
# 190126-17:47:33,472 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:47:33,510 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 190126-17:47:35,320 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 112.82/113.22, Free processors: 0/2.
#                      Currently running:
#                        * spm_l2analysis.level2estimate
#                        * spm_l2analysis.level2estimate
# 190126-17:48:38,618 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.level
nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.multipleregression
# 190126-17:49:17,519 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.multipleregression".
# 190126-17:49:17,530 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.multipleregression" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0001_fwhm_id_8/multipleregression".
# 190126-17:49:17,534 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.multipleregression".
# 190126-17:49:17,551 nipype.workflow INFO:
# 	 [Node] Running "multipleregression" ("nipype.interfaces.spm.model.MultipleRegressionDesign")
# 190126-17:49:19,423 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 112.82/113.22, Free processors: 0/2.
#                      Currently running:
#                        * spm_l2analysis.multipleregression
#                        * spm_l2analysis.multipleregression
# 190126-17:49:30,667 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.multipleregression".
# 190126-17:49:31,434 nipype.workflow INFO:
# 	 [Job 43] Completed (spm_l2analysis.multipleregression).
# 190126-17:49:31,439 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.multipleregression
# 190126-17:49:31,544 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:49:31,549 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.level2estimate" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0002_fwhm_id_8/level2estimate".
# 190126-17:49:31,551 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:49:31,570 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 190126-17:49:33,438 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 112.82/113.22, Free processors: 0/2.
#                      Currently running:
#                        * spm_l2analysis.level2estimate
#                        * spm_l2analysis.multipleregression
# 190126-17:49:41,128 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.multipleregression".
# 190126-17:49:41,444 nipype.workflow INFO:
# 	 [Job 47] Completed (spm_l2analysis.multipleregression).
# 190126-17:49:41,448 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.level2estimate
# 190126-17:49:41,560 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:49:41,565 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.level2estimate" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0001_fwhm_id_8/level2estimate".
# 190126-17:49:41,567 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2estimate".
# 190126-17:49:41,621 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 190126-17:49:43,447 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 112.82/113.22, Free processors: 0/2.
#                      Currently running:
#                        * spm_l2analysis.level2estimate
#                        * spm_l2analysis.level2estimate
# 190126-17:50:51,870 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.level2estimate".
# 190126-17:50:53,518 nipype.workflow INFO:
# 	 [Job 44] Completed (spm_l2analysis.level2estimate).
# 190126-17:50:53,529 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.level2estimate
# 190126-17:50:53,673 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2conestimate".
# 190126-17:50:53,678 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.level2conestimate" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0002_fwhm_id_8/level2conestimate".
# 190126-17:50:53,682 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2conestimate".
# 190126-17:50:53,701 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 190126-17:50:55,521 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 112.82/113.22, Free processors: 0/2.
#                      Currently running:
#                        * spm_l2analysis.level2conestimate
#                        * spm_l2analysis.level2estimate
# 190126-17:51:02,225 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.level2estimate".
# 190126-17:51:03,528 nipype.workflow INFO:
# 	 [Job 48] Completed (spm_l2analysis.level2estimate).
# 190126-17:51:03,533 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.level2conestimate
# 190126-17:51:03,640 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2conestimate".
# 190126-17:51:03,646 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.level2conestimate" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0001_fwhm_id_8/level2conestimate".
# 190126-17:51:03,649 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.level2conestimate".
# 190126-17:51:03,667 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 190126-17:51:05,532 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 112.82/113.22, Free processors: 0/2.
#                      Currently running:
#                        * spm_l2analysis.level2conestimate
#                        * spm_l2analysis.level2conestimate
# 190126-17:51:19,922 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.level2conestimate".
# 190126-17:51:21,545 nipype.workflow INFO:
# 	 [Job 45] Completed (spm_l2analysis.level2conestimate).
# 190126-17:51:21,550 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.level2conestimate
# 190126-17:51:21,656 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.datasink".
# 190126-17:51:21,663 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.datasink" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0002_fwhm_id_8/datasink".
# 190126-17:51:21,665 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.datasink".
# 190126-17:51:21,676 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190126-17:51:21,679 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0002_fwhm_id_8/SPM.mat -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0002_fwhm8/SPM.mat
# 190126-17:51:21,739 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0002_fwhm_id_8/spmT_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0002_fwhm8/spmT_0001.nii
# 190126-17:51:21,904 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0002_fwhm_id_8/spmT_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0002_fwhm8/spmT_0002.nii
# 190126-17:51:22,20 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0002_fwhm_id_8/con_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0002_fwhm8/con_0001.nii
# 190126-17:51:22,137 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0002_fwhm_id_8/con_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0002_fwhm8/con_0002.nii
# 190126-17:51:22,245 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.datasink".
# 190126-17:51:23,547 nipype.workflow INFO:
# 	 [Job 46] Completed (spm_l2analysis.datasink).
# 190126-17:51:23,552 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 113.02/113.22, Free processors: 1/2.
#                      Currently running:
#                        * spm_l2analysis.level2conestimate
# 190126-17:51:28,491 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.level2conestimate".
# 190126-17:51:29,554 nipype.workflow INFO:
# 	 [Job 49] Completed (spm_l2analysis.level2conestimate).
# 190126-17:51:29,559 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 2/2.
# 190126-17:51:29,697 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.datasink".
# 190126-17:51:29,705 nipype.workflow INFO:
# 	 [Node] Setting-up "spm_l2analysis.datasink" in "/data/EFAT/EFAT_output/PT/workingdir/spm_l2analysis/_contrast_id_con_0001_fwhm_id_8/datasink".
# 190126-17:51:29,708 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "spm_l2analysis.datasink".
# 190126-17:51:29,727 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190126-17:51:29,730 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0001_fwhm_id_8/SPM.mat -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0001_fwhm8/SPM.mat
# 190126-17:51:29,796 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0001_fwhm_id_8/spmT_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0001_fwhm8/spmT_0001.nii
# 190126-17:51:29,954 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0001_fwhm_id_8/spmT_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0001_fwhm8/spmT_0002.nii
# 190126-17:51:30,139 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0001_fwhm_id_8/con_0001.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0001_fwhm8/con_0001.nii
# 190126-17:51:30,249 nipype.interface INFO:
# 	 sub: /data/EFAT/EFAT_output/PT/datasink/2ndLevel/_contrast_id_con_0001_fwhm_id_8/con_0002.nii -> /data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0001_fwhm8/con_0002.nii
# 190126-17:51:30,360 nipype.workflow INFO:
# 	 [Node] Finished "spm_l2analysis.datasink".
# 190126-17:51:31,555 nipype.workflow INFO:
# 	 [Job 50] Completed (spm_l2analysis.datasink).
# 190126-17:51:31,558 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 2/2.

# %%
from nilearn.plotting import (plot_stat_map, plot_img)
# %matplotlib inline
anatimg = '/home/soyeon/mni_icbm152_nlin_asym_09c/1mm_T1.nii.gz'

# %%
plot_stat_map(
    '/data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0007_fwhm8/con_0001.nii', title='fwhm=8', dim=1,
    bg_img=anatimg, threshold=2, vmax=8, display_mode='z', cut_coords=(52, 50, 28, 6, 34), cmap='viridis');
# Out:
# /home/soyeon/.local/lib/python3.6/site-packages/nilearn/plotting/displays.py:684: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))

# %%
plot_stat_map(
    '/data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0007_fwhm8/con_0002.nii', title='fwhm=8', dim=1,
    bg_img=anatimg, threshold=2, vmax=8, display_mode='y', cut_coords=(-45, -30, -15, 0, 15), cmap='viridis');
# Out:
# /home/soyeon/.local/lib/python3.6/site-packages/nilearn/plotting/displays.py:684: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))

# %%
from nilearn.plotting import plot_glass_brain
plot_glass_brain(
    '/data/EFAT/EFAT_output/PT/datasink/2ndLevel/spm_con_0007_fwhm8/con_0001.nii', colorbar=True,
    threshold=1, display_mode='lyrz', black_bg=True, vmax=6, title='contrast2 - fwhm=8 - ANTs')
# Out:
# /home/soyeon/.local/lib/python3.6/site-packages/nilearn/plotting/displays.py:684: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))
